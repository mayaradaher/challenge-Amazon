# %% [markdown]
# ## Dataset: book_info

# %%
import pandas as pd

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_parquet("data/raw/book_info.parquet")

# %% [markdown]
# ### Data cleaning

# %%
# remove colum
df = df.drop(columns=["description"])

# %%
# joining a list of strings into a single string
df["authors"] = df["authors"].apply(lambda x: ", ".join(x))

df["categories"] = df["categories"].apply(lambda x: ", ".join(x))

# %%
# remove rows where contain "not available"
mask = ~df["authors"].str.contains("not available", na=False) & ~df[
    "categories"
].str.contains("not available", na=False)

df_book = df.loc[mask].copy()

# %% [markdown]
# ### Exploratory data analysis

# %%
df_book.info()  # data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45105 entries, 0 to 51508
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   isbn        45105 non-null  object
#  1   title       45105 non-null  object
#  2   authors     45105 non-null  object
#  3   categories  45105 non-null  object
# dtypes: object(4)
# memory usage: 1.7+ MB

# %%
df_book[df_book["authors"].str.contains("not available", case=False)]
# Out:
# Empty DataFrame
# Columns: [isbn, title, authors, categories]
# Index: []

# %%
df_book["title"].value_counts().head(5)
# Out:
# title
# Case Closed                                 26
# My Hero Academia                            18
# Black Butler                                16
# Piano Adventures                            14
# The Norton Anthology of World Literature    12
# Name: count, dtype: int64

# %%
# the same title represents different editions/volumes
df_book[df_book["title"].str.contains("case closed", case=False)]
# Out:
#              isbn                                   title           authors  \
# 17703  0062676288  Case Closed #1: Mystery in the Mansion  Lauren Magaziner
# 21610  1421516772                             Case Closed      Gosho Aoyama
# 21611  1421516764                             Case Closed      Gosho Aoyama
# 21612  1421516756                             Case Closed      Gosho Aoyama
# 21613  1421516748                             Case Closed      Gosho Aoyama
# 21614  1421514567                             Case Closed      Gosho Aoyama
# 21619  1421521962                             Case Closed      Gosho Aoyama
# 21620  1421516799                             Case Closed      Gosho Aoyama
# 21621  1421516780                             Case Closed      Gosho Aoyama
# 21625  1421521989                    Case Closed, Vol. 30      Gosho Aoyama
# 21626  1421521970                             Case Closed      Gosho Aoyama
# 21630  142152886X                             Case Closed      Gosho Aoyama
# 21631  1421528851                             Case Closed      Gosho Aoyama
# 21632  1421528843                             Case Closed      Gosho Aoyama
# 21633  1421522004                             Case Closed      Gosho Aoyama
# 21634  1421521997                             Case Closed      Gosho Aoyama
# 21660  1421535009                             Case Closed      Gosho Aoyama
# 21661  1421534991                             Case Closed      Gosho Aoyama
# 21662  1421528894                             Case Closed      Gosho Aoyama
# 21663  1421528886                             Case Closed      Gosho Aoyama
# 21664  1421528878                             Case Closed      Gosho Aoyama
# 21668  1421536102                             Case Closed      Gosho Aoyama
# 21669  1421536099                             Case Closed      Gosho Aoyama
# 21670  1421536080                             Case Closed      Gosho Aoyama
# 21671  1421536072                             Case Closed      Gosho Aoyama
# 21694  1421536129                             Case Closed      Gosho Aoyama
# 21695  1421536137                             Case Closed      Gosho Aoyama
# 21696  1421536110                             Case Closed      Gosho Aoyama
#
#                     categories
# 17703         Juvenile Fiction
# 21610  Comics & Graphic Novels
# 21611  Comics & Graphic Novels
# 21612  Comics & Graphic Novels
# 21613  Comics & Graphic Novels
# 21614  Comics & Graphic Novels
# 21619  Comics & Graphic Novels
# 21620  Comics & Graphic Novels
# 21621  Comics & Graphic Novels
# 21625  Comics & Graphic Novels
# 21626  Comics & Graphic Novels
# 21630  Comics & Graphic Novels
# 21631  Comics & Graphic Novels
# 21632  Comics & Graphic Novels
# 21633  Comics & Graphic Novels
# 21634  Comics & Graphic Novels
# 21660  Comics & Graphic Novels
# 21661  Comics & Graphic Novels
# 21662  Comics & Graphic Novels
# 21663  Comics & Graphic Novels
# 21664  Comics & Graphic Novels
# 21668  Comics & Graphic Novels
# 21669  Comics & Graphic Novels
# 21670  Comics & Graphic Novels
# 21671  Comics & Graphic Novels
# 21694  Comics & Graphic Novels
# 21695  Comics & Graphic Novels
# 21696  Comics & Graphic Novels

# %%
# authored the most number of  books
df_book.groupby("authors")["title"].count().nlargest(10)
# Out:
# authors
# DK                     179
# Stephen King            88
# Disney Book Group       87
# Roger Priddy            69
# William Shakespeare     65
# Dr. Seuss               63
# Brandon Sanderson       55
# Eiichiro Oda            50
# Golden Books            49
# Nora Roberts            47
# Name: title, dtype: int64

# %%
# bottom 5 authors
df_book["authors"].value_counts().tail(5)
# Out:
# authors
# Diane Staehr Fenner, Sydney Snyder                      1
# William L. Heward, Sheila Alber-Morgan, Moira Konrad    1
# Pablo Garcia Loaeza                                     1
# Prince Harry, The Duke of Sussex                        1
# William Guthrie                                         1
# Name: count, dtype: int64

# %%
# top 5 categories
df_book["categories"].value_counts().head(5)
# Out:
# categories
# Fiction                      5988
# Juvenile Fiction             5667
# Juvenile Nonfiction          2682
# Comics & Graphic Novels      2203
# Biography & Autobiography    1711
# Name: count, dtype: int64

# %%
# the categories are inconsistent?
df_book.loc[
    df_book["title"] == "Harry Potter", ["isbn", "title", "categories", "authors"]
]
# Out:
#              isbn         title                           categories  \
# 7473   133831291X  Harry Potter                     Juvenile Fiction
# 9754   0439358078  Harry Potter                       Bildungsromans
# 11153  0545139708  Harry Potter                       Bildungsromans
# 16167  1338311506  Harry Potter                  Juvenile Nonfiction
# 24824  1408890763  Harry Potter  Harry Potter (Fictitious character)
# 29227  0439136350  Harry Potter                       Bildungsromans
# 46937  1608870391  Harry Potter                  Juvenile Nonfiction
#
#                                      authors
# 7473                           J. K. Rowling
# 9754                           J. K. Rowling
# 11153                          J. K. Rowling
# 16167                        British Library
# 24824                        British Library
# 29227                          J. K. Rowling
# 46937  . Warner Bros. Consumer Products Inc.

# %%
# categories: England not seem to be correct
df_book.loc[
    df_book["title"].str.startswith("Harry Potter and the Prisoner of Azkaban")
    & (df_book["authors"] == "J. K. Rowling"),
    ["isbn", "title", "categories", "authors"],
]
# Out:
#              isbn                                              title  \
# 413    0545791340  Harry Potter and the Prisoner of Azkaban: The ...
# 885    0439136369  Harry Potter and the Prisoner of Azkaban - Boo...
# 24329  1338299166           Harry Potter and the Prisoner of Azkaban
# 42047  152660616X  Harry Potter and the Prisoner of Azkaban - Gry...
#
#              categories        authors
# 413    Juvenile Fiction  J. K. Rowling
# 885             England  J. K. Rowling
# 24329  Juvenile Fiction  J. K. Rowling
# 42047  Boarding schools  J. K. Rowling

# %%
df_book.loc[
    df_book["categories"] == "England", ["isbn", "title", "categories", "authors"]
]
# Out:
#              isbn                                              title  \
# 885    0439136369  Harry Potter and the Prisoner of Azkaban - Boo...
# 5410   1338218395   Harry Potter Books 1-7 Special Edition Boxed Set
# 6917   1616649828                         The House on Durrow Street
# 10961  0545044251              Harry Potter and the Sorcerer's Stone
# 23045  1608613763                                     Friends & Foes
# 23046  1608611752                             The Kiss of a Stranger
# 23059  1524413356                                      FORGET ME NOT
# 28057  1789310636                                 The Winter Mystery
# 29465  0439784549             Harry Potter and the Half-Blood Prince
# 31917  1925559173                    A Conquest Impossible to Resist
# 31954  0373010435                                       Four in Hand
# 33992  1640970541                          Fodor's Essential England
# 34509  0385545339                              The Warlow Experiment
# 34800  015670160X                                            Orlando
# 50053  8498387655  Harry Potter y la cámara secreta (Harry Potter...
# 50634  1505408768                                       Unsafe Haven
# 50637  1516841107                   Surviving The Evacuation, Book 7
#
#       categories                                            authors
# 885      England                                      J. K. Rowling
# 5410     England                                      J. k. Rowling
# 6917     England                                      Galen Beckett
# 10961    England                                      J. K. Rowling
# 23045    England                                      Sarah M. Eden
# 23046    England                                      Sarah M. Eden
# 23059    England                                      Sarah M. Eden
# 28057    England                                       Faith Martin
# 29465    England                                      J. K. Rowling
# 31917    England                                  Stephanie Laurens
# 31954    England                    Stephanie Laurens, Sophia James
# 33992    England  Fodor's Travel Publications, Inc. Staff, Fodor...
# 34509    England                                        Alix Nathan
# 34800    England                                     Virginia Woolf
# 50053    England                                      J. K. Rowling
# 50634    England                                       Frank Tayell
# 50637    England                                       Frank Tayell

# %% [markdown]
# ### Merge dataset: purchases

# %%
# select columns
columns = [
    "Survey ResponseID",
    "ASIN/ISBN (Product Code)",
    "Category",
    "Quantity",
    "Purchase Price Per Unit",
    "Purchase Total",
]
df_purchases = pd.read_parquet("data/ready/amazon_purchases.parquet", columns=columns)

# %%
# Filter by ISBN with 10 and 13 digits and Category Abis book
df_purchases = df_purchases[
    (df_purchases["Category"] == "Abis book")
    & (df_purchases["ASIN/ISBN (Product Code)"].str.len().isin([10, 13]))
]

# %%
df_book_purchases = pd.merge(
    df_book,
    df_purchases,
    left_on="isbn",
    right_on="ASIN/ISBN (Product Code)",
    how="inner",
)
df_book_purchases = df_book_purchases.drop(columns=["ASIN/ISBN (Product Code)"])

# %%
df_book_purchases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68906 entries, 0 to 68905
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   isbn                     68906 non-null  object
#  1   title                    68906 non-null  object
#  2   authors                  68906 non-null  object
#  3   categories               68906 non-null  object
#  4   Survey ResponseID        68906 non-null  category
#  5   Category                 68906 non-null  category
#  6   Quantity                 68906 non-null  int8
#  7   Purchase Price Per Unit  68906 non-null  float64
#  8   Purchase Total           68906 non-null  float64
# dtypes: category(2), float64(2), int8(1), object(4)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Merge dataset: survey

# %%
# select columns
columns = [
    "Survey ResponseID",
    "Q-demos-gender",
    "Q-demos-age",
    "Q-demos-education",
    "Q-demos-state",
    "Q-demos-income",
]

df_survey = pd.read_parquet("data/ready/amazon_survey.parquet", columns=columns)

# %%
df_book_purchases_survey = pd.merge(
    df_book_purchases,
    df_survey,
    on="Survey ResponseID",
    how="inner",
)

# %%
# top 5 categories
df_book_purchases_survey["categories"].value_counts().head(5)
# Out:
# categories
# Juvenile Fiction             10066
# Fiction                       9411
# Juvenile Nonfiction           4663
# Comics & Graphic Novels       3338
# Biography & Autobiography     2689
# Name: count, dtype: int64

# %%
# top 5 title
df_book_purchases_survey["title"].value_counts().head(5)
# Out:
# title
# Harry Potter and the Sorcerer's Stone    84
# Becoming                                 75
# Where the Crawdads Sing                  61
# Atomic Habits                            60
# The Very Hungry Caterpillar              58
# Name: count, dtype: int64

# %%
# best selling authors
df_book_purchases_survey.groupby("authors")["Survey ResponseID"].nunique().nlargest(10)
# Out:
# authors
# DK                   203
# J. K. Rowling        173
# Stephen King         138
# Dr. Seuss            124
# Colleen Hoover       111
# Roger Priddy         110
# Eric Carle            92
# Dav Pilkey            89
# Scholastic            84
# Disney Book Group     82
# Name: Survey ResponseID, dtype: int64

# %%
df_book_purchases_survey["Survey ResponseID"].nunique()
# Out:
# 4032

# %%
# book purchases of a specific user
df_book_purchases_survey[
    df_book_purchases_survey["Survey ResponseID"] == "R_phoOTxhiHcWo7lL"
]
# Out:
#              isbn                         title         authors  \
# 16047  0805071636              The Colors of Us      Karen Katz
# 29623  0692045635  And That's Why She's My Mama  Tiarra Nazario
# 66489  1733079580            Honky in the House    Jay Moriarty
# 66490  1499806663           Pepe and the Parade     Tracey Kyle
#
#                       categories  Survey ResponseID   Category  Quantity  \
# 16047     Family & Relationships  R_phoOTxhiHcWo7lL  Abis book         1
# 29623           Juvenile Fiction  R_phoOTxhiHcWo7lL  Abis book         1
# 66489  Biography & Autobiography  R_phoOTxhiHcWo7lL  Abis book         1
# 66490           Juvenile Fiction  R_phoOTxhiHcWo7lL  Abis book         1
#
#        Purchase Price Per Unit  Purchase Total Q-demos-gender Q-demos-age  \
# 16047                     7.99            7.99         Female     45 - 54
# 29623                     9.95            9.95         Female     45 - 54
# 66489                    18.05           18.05         Female     45 - 54
# 66490                    12.99           12.99         Female     45 - 54
#
#                 Q-demos-education Q-demos-state Q-demos-income
# 16047  High school diploma or GED         Texas   $25 - $49.9K
# 29623  High school diploma or GED         Texas   $25 - $49.9K
# 66489  High school diploma or GED         Texas   $25 - $49.9K
# 66490  High school diploma or GED         Texas   $25 - $49.9K

# %%
# top 10 users with the highest books purchase total amounts
top10_survey = (
    df_book_purchases_survey.groupby("Survey ResponseID")["Purchase Total"]
    .sum()
    .nlargest(10)
    .index
)

# %%
# filter dataframe with top 10 users
df_top10_book_purchases_survey = df_book_purchases_survey[
    df_book_purchases_survey["Survey ResponseID"].isin(top10_survey)
]

# %%
df_top10_book_purchases_survey.head(1)
# Out:
#          isbn                    title          authors  categories  \
# 2  1506223605  GED Test Prep Plus 2018  Caren Van Slyke  Study Aids
#
#    Survey ResponseID   Category  Quantity  Purchase Price Per Unit  \
# 2  R_277i50HinKYVoY9  Abis book         1                    15.94
#
#    Purchase Total Q-demos-gender Q-demos-age           Q-demos-education  \
# 2           15.94         Female     35 - 44  High school diploma or GED
#
#   Q-demos-state Q-demos-income
# 2        Nevada   $50 - $74.9K

# %% [markdown]
# ### Save dataset

# %%
selected_columns = [
    "Survey ResponseID",
    "title",
    "authors",
    "categories",
    "Q-demos-gender",
    "Q-demos-age",
    "Q-demos-education",
    "Q-demos-state",
    "Q-demos-income",
]
df_top10_book_purchases_survey = df_top10_book_purchases_survey[
    selected_columns
].reset_index(drop=True)

# %% [markdown]
# #### Grouping Survey Data: Combining Demographics and Book Purchases

# %%
df_top10_book_purchases_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Survey ResponseID  2225 non-null   object
#  1   title              2225 non-null   object
#  2   authors            2225 non-null   object
#  3   categories         2225 non-null   object
#  4   Q-demos-gender     2225 non-null   category
#  5   Q-demos-age        2225 non-null   category
#  6   Q-demos-education  2225 non-null   category
#  7   Q-demos-state      2225 non-null   category
#  8   Q-demos-income     2225 non-null   category
# dtypes: category(5), object(4)
# memory usage: 83.9+ KB

# %%
# unique IDs
unique_ids = df_top10_book_purchases_survey["Survey ResponseID"].unique()

# create separate dictionaries for demographic and book purchases
demographic_data = {}
book_data = {survey_id: [] for survey_id in unique_ids}

# iterate over the dataframe rows
for _, row in df_top10_book_purchases_survey.iterrows():
    survey_id = row["Survey ResponseID"]

    # extract demographic information
    demographic_info = {
        "Gender": row["Q-demos-gender"],
        "Age": row["Q-demos-age"],
        "Education level": row["Q-demos-education"],
        "State": row["Q-demos-state"],
        "Household income": row["Q-demos-income"],
    }

    # extract book purchases
    book_info = {
        "authors": row["authors"],
        "categories": row["categories"],
        "title": row["title"],
    }

    # store demographic information (once per ID)
    if survey_id not in demographic_data:
        demographic_data[survey_id] = demographic_info

    # add purchase information to the corresponding group in the dictionary
    book_data[survey_id].append(book_info)

# combine informations into a DataFrame
combined_data = []
for survey_id in unique_ids:
    user_info = demographic_data[survey_id]
    books = book_data[survey_id]
    combined_data.append(
        {
            "Survey ResponseID": survey_id,
            "demographic": user_info,
            "books": books,
        }
    )

# converter do df
df_grouped = pd.DataFrame(combined_data)


# save json file
df_grouped.to_json("data/ready/top10_grouped_book_purchases.json")
